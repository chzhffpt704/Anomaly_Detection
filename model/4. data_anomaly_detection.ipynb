# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
from matplotlib import font_manager, rc
import anomaly

# %%
ori_path = '../5. Dataset_combine/'
csv_list = os.listdir(ori_path + '3. csv/')
plot_list = os.listdir(ori_path + '2. Plot/')
motor_list = list(set(map(lambda x: x.split('_')[1],csv_list)))
mul_label = pd.read_csv('../5. Dataset_combine/label_check.csv', encoding='cp949')

font_path = "C:/Windows/Fonts/malgun.ttf" # 사용할 폰트명 경로 삽입
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %% [markdown]
# ## 성능 검증 지표 확인하기
# * Var 정상보다 10% 더 높을 경우 고장
# 1. 초기 50초 값을 저장한다.
# 2. 초기 값과 이후 값을 비교하여 더 높아졌을 경우 문제가 발생하였다 판단

# %% [markdown]
# ### 1. 정상 vs 회전체 불평형

# %%
target = '회전체불평형'
use_method = 'Var'
anomaly.plot_make_v1(motor_list, csv_list, target, use_method, ori_path, plus = 3)

# %% [markdown]
# ### 2. 정상 vs 베어링불량

# %%
target = '베어링'
use_method = 'Var'
anomaly.plot_make_v1(motor_list, csv_list, target, use_method, ori_path)

# %% [markdown]
# ### 3. 정상 vs 축정렬불량

# %%
target = '축정렬불량'
use_method = 'Var'
anomaly.plot_make_v1(motor_list, csv_list, target, use_method, ori_path)

# %% [markdown]
# ### 4. 정상 VS 벨트느슨함

# %%
target = '벨트느슨함'
use_method = 'Var'
anomaly.plot_make_v1(motor_list, csv_list, target, use_method, ori_path)
